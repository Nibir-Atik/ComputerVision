# %% [markdown]
# <a href="https://colab.research.google.com/github/Nibir-Atik/ComputerVision/blob/main/Task01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Example 1: Image open, show, save using Pillow
from google.colab import drive
drive.mount('/content/drive')

# Import Pillow
from PIL import Image
from IPython.display import display


img_path = "/content/drive/MyDrive/Computer vision/bird1.jpg"

img = Image.open(img_path)
img
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=612x408>

# %%
w_h = (800,700) # tuple declared with value 800, 700
img.thumbnail(w_h)  # change dimension of the image
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=80x53>

# %%
img.save("bird2.png","PNG")
#Question: what other parameters can be used while saving as JPEG by img.save() method

# %%
x = img.rotate(60)
x
# Out:
# <PIL.Image.Image image mode=RGB size=80x53>

# %%
a = img.transpose(Image.FLIP_LEFT_RIGHT) # try Image.FLIP_TOP_BOTTOM
a
# Out:
# <PIL.Image.Image image mode=RGB size=80x53>

# %%
b = img.transpose(Image.ROTATE_90)  # try Image.ROTATE_180  or Image.ROTATE_270
b
# Out:
# <PIL.Image.Image image mode=RGB size=53x80>

# %%
x.save("output1.jpg", format="JPEG", quality=80, optimize=True, progressive=True)

# %%
from PIL import ImageFilter

a = img.filter(ImageFilter.BLUR)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3134770728.py in <cell line: 0>()
# ----> 1 a = img.filter(ImageFilter.BLUR)
#       2 a
#
# NameError: name 'ImageFilter' is not defined
